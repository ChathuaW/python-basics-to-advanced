# %% [markdown]
# # variable is a container for a value (string, integer, float, boolean)

# %% [markdown]
# # Strings

# %%
print("I Love Pizza !")
# Out:
# I Love Pizza !

# %%
print("It is really Good")
# Out:
# It is really Good

# %%
first_name = "Ceylon"
food = "pizza"
email = "ceylonstat9@gmail.com"

# %%
print(first_name)
# Out:
# Ceylon

# %%
print(f"Hello {first_name}")
# Out:
# Hello Ceylon

# %%
print(f"You like {food}")
# Out:
# You like pizza

# %%
print(f"Your email is : {email}")
# Out:
# Your email is : ceylonstat9@gmail.com

# %% [markdown]
# # Integers

# %%
age = 25
quantity = 3
num_of_students = 30

# %%
print(f"You are {age} years old")
# Out:
# You are 25 years old

# %%
print(f"you are buying {quantity} items")
# Out:
# you are buying 3 items

# %%
print(f"There are {num_of_students} in your class")
# Out:
# There are 30 in your class

# %% [markdown]
# # Float

# %%
price = 10.99
GPA = 3.2
distance = 5.5

# %%
print(f"Price is ${price}")
# Out:
# Price is $10.99

# %%
print(f"Your GPA is {GPA}")
# Out:
# Your GPA is 3.2

# %%
print(f"You ran {distance}Km")
# Out:
# You ran 5.5Km

# %% [markdown]
# # Boolean

# %%
is_student = False

# %%
if is_student :
    print("You are a student")
    
else :
    print("You are not a student")
# Out:
# You are not a student

# %%
for_sale = True

if for_sale :
    print("That item for sale")
else :
    print("That item not for sale")
# Out:
# That item for sale

# %%
is_online = True

if is_online :
    print("You are online")
else :
    print("You are offline")
# Out:
# You are online

# %% [markdown]
# # Type Casting is the process of converting a variable from one data type to another str(), int(), float(), bool()

# %%
Name = "Ceylon Stat"
Age = 25
GPA =3.2
is_student = True

# %%
print(type(Name))
print(type(Age))
print(type(GPA))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
GPA = int(GPA)

# %%
type(GPA)
# Out:
# int

# %%
GPA
# Out:
# 3

# %% [markdown]
# # Input() = A function that prompts the user to enter data returns the entered data as string

# %%
input("What is your name :")
# Out:
# What is your name :Ceylon Stat
# 'Ceylon Stat'

# %%
name = input("What is your name :")
# Out:
# What is your name :Ceylon Stat

# %%
print(f"Helo {name} !")
# Out:
# Helo Ceylon Stat !

# %%
Age = input("How old are you ? ")
# Out:
# How old are you ? 25

# %%
print(f"You are {Age} years old")
# Out:
# You are 25 years old

# %%
type(Age)
# Out:
# str

# %% [markdown]
# # Exercise 1 Rectangle Area Calc

# %%
length = float(input("Enter the length : "))
width = float(input("Enter the width : "))
# Out:
# Enter the length : 34
# Enter the width : 56

# %%
area = length * width * 0.5

# %%
print(f"Area is {area}cm^2")
# Out:
# Area is 952.0cm^2

# %%
Item = input("What item would you buy : ")
price = float(input("What is the price : "))
quantity = float(input("How many would you like : "))
# Out:
# What item would you buy : shirt
# What is the price : 3
# How many would you like : 1400

# %%
total = price * quantity 
print(f"Total price is {total}")
# Out:
# Total price is 4200.0

# %% [markdown]
# # Arithmatic & Math

# %%
friend = 0

# %%
friend = friend + 1

# %%
print(friend)
# Out:
# 1

# %%
friend += 2

# %%
print(friend)
# Out:
# 3

# %%
friend -= 3

# %%
print(friend)
# Out:
# 0

# %%
friend *= 4

# %%
print(friend)
# Out:
# 0

# %%
friend = friend/4

# %%
print(friend)
# Out:
# 0.0

# %%
friend /= 4

# %%
print(friend)
# Out:
# 0.0

# %%
friend += 4

# %%
print(friend)
# Out:
# 4.0

# %%
friend = friend ** 2

# %%
print(friend)
# Out:
# 16.0

# %%
friend **= 2

# %%
remainder = friend % 3

# %%
print(remainder)
# Out:
# 1.0

# %%
x = 3.14
y = -4
z = 5

# %%
result = round(x)

# %%
print(result)
# Out:
# 3

# %%
print(abs(y))
# Out:
# 4

# %%
result = pow(4,3)
print(result)
# Out:
# 64

# %%
maximum = max(x,y,z)
print(maximum)
# Out:
# 5

# %%
minimum = min(abs(x),abs(y),abs(z))
print(minimum)
# Out:
# 3.14

# %%
import math

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
print(math.sqrt(16))
# Out:
# 4.0

# %%
radius = float(input("Enter the radius of a circle : "))
circumference = 2 * math.pi * radius
print(f"The circumference is {round(circumference,2)}")
# Out:
# Enter the radius of a circle : 7
# The circumference is 43.98

# %%
radius = float(input("Enter the radius of a circle : "))
area = math.pi * pow(radius,2)
print(f"The area is {round(area,2)}")
# Out:
# Enter the radius of a circle : 7
# The area is 153.94

# %%
First_1 = float(input("Enter side A : "))
First_2 = float(input("Enter side B : "))

area = math.sqrt(pow(First_1,2) + pow(First_2,2))
print(f"The area of the Rectangle Triangle is {round(area,2)}cm")
# Out:
# Enter side A : 3
# Enter side B : 4
# The area of the Rectangle Triangle is 5.0cm

# %% [markdown]
# # if = Do some code only IF some condition is True Else do something else

# %%
age = int(input("Enter your age : "))
if age >= 18:
    print("You are now signed up!")
# Out:
# Enter your age : 25
# You are now signed up!

# %%
age = int(input("Enter your age : "))
if age >= 18:
    print("You are now signed up !")
else :
    print("You must be 18+ to sign up")
# Out:
# Enter your age : 34
# You are now signed up !

# %%
age = int(input("Enter your age : "))
if age >= 18:
    print("You are now signed up")
elif age < 0 :
    print("You haven't been born yet")
else :
    print("You must be 18+ to sign up")
# Out:
# Enter your age : 12
# You must be 18+ to sign up

# %%
response = input("Would you like food? (Y/N) : ")

if response == "Y":
    print("Have some foods")
else:
    print("No food for you !")
# Out:
# Would you like food? (Y/N) : Y
# Have some foods

# %%
Name = input("Enter your name : ")

if Name == "" :
    print("You didn't type your name")
else :
    print(f"Hello {Name}! ")
# Out:
# Enter your name : Chathula
# Hello Chathula!

# %%
for_sale = True

if for_sale:
    print("This item for sale")
else:
    print("This item is NOT for sale")
# Out:
# This item for sale

# %% [markdown]
# # Python Calculator

# %%
operator = input("Enter the operator (+,-,/,*) :")
num_1 = float(input("Enter your first number : "))
num_2 = float(input("Enter your second number : "))

if operator == "+":
    result = num_1 + num_2
    print(round(result,2))
elif operator == "-":
    result = num_1 - num_2
    print(round(result,2))
elif operator == "*":
    result = num_1 * num_2
    print(round(result,2))
elif operator == "/":
    result = num_1/num_2
    print(round(result,2))
else:
    print("Syntax Error")
# Out:
# Enter the operator (+,-,/,*) :*
# Enter your first number : 67.89
# Enter your second number : 563.97
# 38287.92

# %% [markdown]
# # Python Weight Converter

# %%
weight = float(input("Enter your weight : "))
unit = input("Kilograms or Pounds ? (K or L) : ")

if unit == "K" :
    weight = weight * 2.205
    unit = "Lbs"
elif unit == "L" :
    weight = weight/2.205
    unit = "Kg"
else :
    print(f"{unit} is not valid")
    
print(f"Your Weight is {round(weight,2)}{unit}")
# Out:
# Enter your weight : 34
# Kilograms or Pounds ? (K or L) : L
# Your Weight is 15.42Kg

# %% [markdown]
# # Temperature Conversion Program

# %%
unit = input("Is the temperature in Celsius or Fahrenheit (C/F) :")
temp = float(input("Enter your Temperature : "))

if unit == "C":
    result = round((9 * temp)/5 + 32,1) 
    print(f"The temperature in fahrenheit {result}")
elif unit == "F":
    result = round((temp - 32)* 5/9,1)
    print(f"The temperature in celsius {result}")
else :
    print(f"{unit} is invalid")
# Out:
# Is the temperature in Celsius or Fahrenheit (C/F) :R
# Enter your Temperature : 56
# R is invalid

# %% [markdown]
# # Logical Operators = Ievaluate multiple conditions (or, and, not)
# ## or = at least one condition must be True
# ## and = both conditions must be True
# ## not = inverts the condition (not False, not True)

# %%
temp = 25
is_raining = True

if temp > 35 or temp < 0 or is_raining :
    print("The outdoor event is cancelled")
else :
    print("The outdoor event is still scheduled")
# Out:
# The outdoor event is cancelled

# %%
temp = 7
is_sunny = True 

if temp >= 28 and is_sunny :
    print("It is HOT Outside 🥵")
    print("It is SUNNY ☀️ ")
elif temp <= 0 and is_sunny :
    print("It is COLD Outside 🥶")
    print("It is sunny ☀️")
elif 28 > temp > 0 and is_sunny :
    print('It is WARM Outside')
    print("It is SUNNY ☀️ ")
# Out:
# It is WARM Outside
# It is SUNNY ☀️

# %% [markdown]
# # conditional expression = A one-line shortcut for the If-else statement (ternary operator)
#
# ## Print or assign one of two values based on a condition
# ## X if condition else

# %%
num = -5

print("Positive" if num > 0 else "Negative")
# Out:
# Negative

# %%
num = 6

result = "Even" if num % 2 == 0 else "ODD"

print(result)
# Out:
# Even

# %%
a = 16
b = 7

print(a if a>b else b)
# Out:
# 16

# %%
age = 25

print("Adult" if age > 18 else "Child")
# Out:
# Adult

# %% [markdown]
# # Strings Methods

# %%
name = input("Enter your name : ")
print(len(name))
# Out:
# Enter your name : Chathula Weerasinghe
# 20

# %%
name = input('Enter your name : ')
print(name.find(" "))
# Out:
# Enter your name : cgha hjh
# 4

# %%
name = input('Enter your name : ')
print(name.find("a"))
# Out:
# Enter your name : gjgfgjagfg
# 6

# %%
name = input('Enter your name : ')
print(name.find("y"))
# Out:
# Enter your name : yvbkm
# 0

# %%
name = input('Enter your name : ')
print(name.rfind(" "))
# Out:
# Enter your name : hfhj kjghkg kgkjhjk hgkhgj
# 19

# %%
name = input('Enter your name : ')
print(name.capitalize())
# Out:
# Enter your name : bcghfg hjhj
# Bcghfg hjhj

# %%
name = input('Enter your name : ')
print(name.upper())
# Out:
# Enter your name : tiga
# TIGA

# %%
name = input('Enter your name : ')
print(name.lower())
# Out:
# Enter your name : DFGDHGcvnbvHGFFddfgs
# dfgdhgcvnbvhgffddfgs

# %%
name = input('Enter your name : ')
print(name.isdigit())
# Out:
# Enter your name : 7587
# True

# %%
name = input('Enter your name : ')
print(name.count("a"))
# Out:
# Enter your name : Chathula
# 2

# %%
name = input('Enter your phone number : ')
print(name.replace("-"," "))
# Out:
# Enter your phone number : 077-9080659
# 077 9080659

# %%
name = input('Enter your phone number : ')
print(name.replace("-",""))
# Out:
# Enter your phone number : 077-90-80-659
# 0779080659

# %% [markdown]
# # indexing = accessing elements of a sequence using [] (indexing operator) [start : end : step]

# %%
credit_number = "1234-5678-9012-3456"

credit_number[1]
# Out:
# '2'

# %%
credit_number[0:4]
# Out:
# '1234'

# %%
credit_number[5:9]
# Out:
# '5678'

# %%
credit_number[5:]
# Out:
# '5678-9012-3456'

# %%
credit_number[-2]
# Out:
# '5'

# %%
credit_number[::2]
# Out:
# '13-6891-46'

# %%
credit_number[::3]
# Out:
# '146-136'

# %%
last_digit = credit_number[-4:]
print(f"XXXX-XXXX-XXXX-{last_digit}")
# Out:
# XXXX-XXXX-XXXX-3456
